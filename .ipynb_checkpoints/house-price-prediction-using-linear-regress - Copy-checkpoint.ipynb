# %% [markdown]
# # Project Abtract:

# %% [markdown]
# The project focuses on analyzing residential property prices to gain insights into the factors influencing the housing market. By examining various variables such as property characteristics, location, market trends, and economic indicators, this project aims to provide a comprehensive understanding of the factors driving home prices and identify key trends and patterns.
#
# The project utilizes a dataset containing information on residential properties, including features such as square footage, number of bedrooms and bathrooms, location attributes (e.g., neighborhood, proximity to amenities), and corresponding sale prices. By analyzing these variables, the project seeks to uncover correlations and trends that can help stakeholders understand the dynamics of the housing market and make informed decisions regarding real estate investments, pricing strategies, and policy development.
#
# Through exploratory data analysis and statistical modeling techniques, the project aims to identify the key factors influencing home prices. This includes assessing the impact of property characteristics (e.g., size, amenities), location factors (e.g., proximity to schools, transportation), and market trends (e.g., supply and demand, interest rates) on property values. Additionally, the project explores the relationships between economic indicators (e.g., GDP growth, employment rates) and home prices to understand the broader macroeconomic influences on the housing market.
#
# The outcomes of this project have implications for real estate professionals, investors, policymakers, and prospective homeowners. Real estate professionals can utilize the findings to better understand market trends, advise clients, and develop effective pricing strategies. Investors can gain insights into factors that drive property value appreciation and identify lucrative investment opportunities. Policymakers can use the findings to inform housing policies, zoning regulations, and urban planning initiatives. Prospective homeowners can make more informed decisions regarding property purchases, taking into account factors that influence home prices and long-term value appreciation.

# %% [markdown]
# # Columns Details

# %% [markdown]
# date: This column represents the date associated with the property listing or sale.
#
# price: This column denotes the price of the property.
#
# bedrooms: This column indicates the number of bedrooms in the property.
#
# bathrooms: This column represents the number of bathrooms in the property.
#  ->Full bathroom (1.0): Includes a sink, toilet, and a bath/shower.
#  ->Half bathroom (0.5): Includes only a sink and a toilet, without a bath or shower.
#  ->Three-quarter bathroom (0.75): Includes a sink, toilet, and a shower but no bathtub.
# sqft_living: This column denotes the total living area of the property in square feet.
#
# sqft_lot: This column represents the total area of the lot or land on which the property is situated, measured in square feet.
#
# floors: This column indicates the number of floors in the property.
#
# waterfront: This column is a binary indicator (e.g., 0 or 1) that represents whether the property has a waterfront view.
#
# view: This column indicates the level of view from the property, which could be a rating or a categorical value.
#
# condition: This column represents the overall condition of the property, which could be a rating or a categorical value.
#
# sqft_above: This column denotes the square footage of the property that is above ground level.
#
# sqft_basement: This column represents the square footage of the property's basement, if applicable.
#
# yr_built: This column indicates the year the property was originally built.
#
# yr_renovated: This column represents the year the property was last renovated, if applicable.
#
# street: This column specifies the street address or location of the property.
#
# city: This column indicates the city where the property is located.
#
# statezip: This column provides the state and ZIP code of the property.
#
# country: This column represents the country where the property is located.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot  as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# **Loading Dataset**

# %%
dataset = pd.read_csv('data.csv')
dataset.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(3), int64(10), object(5)
# memory usage: 647.0+ KB

# %%
dataset.shape
# Out:
# (4600, 18)

# %%
dataset.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %% [markdown]
# **Delete date column** Date column is irrelevant

# %%
dataset.drop(['date'], axis = 1, inplace = True)
dataset.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country
# 0      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1           709 W Blaine St    Seattle  WA 98119     USA
# 2  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3           857 170th Pl NE   Bellevue  WA 98008     USA
# 4         9105 170th Ave NE    Redmond  WA 98052     USA

# %% [markdown]
# **Checking how many different Countries are there**

# %%
dataset.country.value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %% [markdown]
# Deleting the country column as all the records have the same country, hence irrelevant

# %%
dataset.drop(['country'], axis = 1, inplace = True)
dataset.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip
# 0      18810 Densmore Ave N  Shoreline  WA 98133
# 1           709 W Blaine St    Seattle  WA 98119
# 2  26206-26214 143rd Ave SE       Kent  WA 98042
# 3           857 170th Pl NE   Bellevue  WA 98008
# 4         9105 170th Ave NE    Redmond  WA 98052

# %% [markdown]
# Since we already have statezip, we can safely delete street and city.

# %%
dataset.drop(['street', 'city'], axis = 1, inplace = True)
dataset.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#    statezip
# 0  WA 98133
# 1  WA 98119
# 2  WA 98042
# 3  WA 98008
# 4  WA 98052

# %% [markdown]
# **Checking for null values**

# %%
dataset.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# statezip         0
# dtype: int64

# %% [markdown]
# *No null values present*

# %% [markdown]
# # General corellation analysis

# %%
dataset.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'statezip'],
#       dtype='object')

# %%
cordataset=dataset.drop(["statezip"],axis=1)

# %%
a4_dims = (10, 8)
fig, ax = plt.subplots(figsize=a4_dims)
cor = cordataset.corr()
sns.heatmap(cor, annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # Analysis on number of bedroom feature

# %% [markdown]
# corellation of price with no. of bedrooms

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x = dataset.bedrooms, y = dataset.price)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# *0 & 9 bedrooms are probably an outlier. Let's dive deeper*

# %% [markdown]
# Let's get the count  of respective no. of bedrooms

# %%
dataset.groupby('bedrooms').price.agg([len, min, max])
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\3376453444.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   dataset.groupby('bedrooms').price.agg([len, min, max])
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\3376453444.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   dataset.groupby('bedrooms').price.agg([len, min, max])
#            len        min         max
# bedrooms
# 0            2  1095000.0   1295648.0
# 1           38        0.0    540000.0
# 2          566        0.0   1695000.0
# 3         2032        0.0  26590000.0
# 4         1531        0.0   4489000.0
# 5          353        0.0   7062500.0
# 6           61        0.0   3100000.0
# 7           14   280000.0   3200000.0
# 8            2   340000.0   1970000.0
# 9            1   599999.0    599999.0

# %% [markdown]
# *Hence proved that 0 & 9 are outliers. Let's remove them*

# %%
df = dataset[(dataset.bedrooms > 0) & (dataset.bedrooms < 9)].copy()

# %%
df.shape
# Out:
# (4597, 14)

# %% [markdown]
# # Analysis on the zipcode feature

# %% [markdown]
# Checking for unique zip code

# %%
df.statezip.value_counts()
# Out:
# statezip
# WA 98103    147
# WA 98052    135
# WA 98117    132
# WA 98115    130
# WA 98006    110
#            ...
# WA 98047      6
# WA 98288      3
# WA 98050      2
# WA 98354      2
# WA 98068      1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# *All the zip codes are of Washington. Let's do a correlation analysis of zip codes*

# %%
a4_dims = (5, 18)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax = ax, x = df.price, y = df.statezip)
# Out:
# <Axes: xlabel='price', ylabel='statezip'>

# %% [markdown]
# Let's look at the distribution of price

# %%
a4_dims = (15, 8)
fig, ax = plt.subplots(figsize=a4_dims)
sns.distplot(a = df.price, bins = 1000, color = 'r', ax = ax)
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\2585100591.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a = df.price, bins = 1000, color = 'r', ax = ax)
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# Groupby on price

# %%
df.price.agg([min, max])
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\1315707.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.price.agg([min, max])
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\1315707.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.price.agg([min, max])
# min           0.0
# max    26590000.0
# Name: price, dtype: float64

# %% [markdown]
# **How many instances are there with price = 0?**

# %%
len(df[(df.price == 0)])
# Out:
# 49

# %% [markdown]
# *need to set some price for these records*

# %% [markdown]
# # Analysis on bathroom feature w.r.t. price

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x = df.bathrooms, y = df.price)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
df['statezip'] = df['statezip'].str.replace('WA ', '')
df['statezip'] = pd.to_numeric(df['statezip'])

# %% [markdown]
# # Analysis on all the instances whose price is 0

# %% [markdown]
# Getting all those instances

# %%
zero_price = df[(df.price == 0)].copy()
zero_price.shape
# Out:
# (49, 14)

# %%
zero_price.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 4354    0.0         3       1.75         1490     10125     1.0           0
# 4356    0.0         4       2.75         2600      5390     1.0           0
# 4357    0.0         6       2.75         3200      9200     1.0           0
# 4358    0.0         5       3.50         3480     36615     2.0           0
# 4361    0.0         5       1.50         1500      7112     1.0           0
#
#       view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 4354     0          4        1490              0      1962             0
# 4356     0          4        1300           1300      1960          2001
# 4357     2          4        1600           1600      1953          1983
# 4358     0          4        2490            990      1983             0
# 4361     0          5         760            740      1920             0
#
#       statezip
# 4354     98001
# 4356     98199
# 4357     98146
# 4358     98075
# 4361     98166

# %% [markdown]
# Let's get the unique value of the most important features

# %%
sns.distplot(zero_price.sqft_living)
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\2430850287.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(zero_price.sqft_living)
# <Axes: xlabel='sqft_living', ylabel='Density'>

# %% [markdown]
# *Most of the 0 price houses are in the range 1000 - 5000 sqft*

# %% [markdown]
# Let's find more correlation between the 0 price houses

# %%
zero_price.agg([min, max, 'mean', 'median'])
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\3246869973.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   zero_price.agg([min, max, 'mean', 'median'])
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\3246869973.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   zero_price.agg([min, max, 'mean', 'median'])
#         price  bedrooms  bathrooms  sqft_living       sqft_lot  floors  \
# min       0.0  1.000000    1.00000   720.000000    3500.000000     1.0
# max       0.0  6.000000    6.25000  8020.000000  188200.000000     3.0
# mean      0.0  3.979592    2.69898  2787.142857   16453.306122     1.5
# median    0.0  4.000000    2.50000  2600.000000    9000.000000     1.5
#
#         waterfront      view  condition   sqft_above  sqft_basement  \
# min       0.000000  0.000000   2.000000   720.000000       0.000000
# max       1.000000  4.000000   5.000000  8020.000000    1950.000000
# mean      0.061224  0.795918   3.673469  2295.714286     491.428571
# median    0.000000  0.000000   3.000000  1990.000000       0.000000
#
#            yr_built  yr_renovated     statezip
# min     1920.000000      0.000000  98001.00000
# max     2013.000000   2009.000000  98199.00000
# mean    1969.918367    812.714286  98077.77551
# median  1962.000000      0.000000  98065.00000

# %% [markdown]
# **We are going to use common ranges from the above table to get similar records from the original dataset and non-zero price to set the values of 0 price instances**

# %%
sim_from_ori = df[(df.bedrooms == 4) & (df.bathrooms > 1) & (df.bathrooms < 4) & (df.sqft_living > 2500) & (df.sqft_living < 3000) & (df.floors < 3) & (df.yr_built < 1970)].copy()

# %%
sim_from_ori.shape
# Out:
# (79, 14)

# %%
sim_from_ori.head()
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 11   1400000.0         4       2.50         2920      4000     1.5
# 172   407000.0         4       2.25         2810     23400     1.0
# 207   360000.0         4       2.00         2680     18768     1.0
# 257   749950.0         4       2.75         2600      6050     2.0
# 261   581000.0         4       2.00         2510     13695     1.0
#
#      waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 11            0     0          5        1910           1010      1909
# 172           0     1          3        1710           1100      1958
# 207           0     0          5        2680              0      1965
# 257           0     0          5        1960            640      1949
# 261           0     0          4        1280           1230      1961
#
#      yr_renovated  statezip
# 11           1988     98105
# 172          2004     98198
# 207             0     98001
# 257             0     98116
# 261          2001     98033

# %% [markdown]
# Get the average price of these instances

# %%
sim_from_ori.price.mean()
# Out:
# 735475.037070886

# %% [markdown]
# Let's confirm this by comparing with the other house price of the same yr_built and having similar sq_ft

# %%
yr_sqft = df[(df.sqft_living > 2499) & (df.sqft_living < 2900)].copy()
yr_price_avg = yr_sqft.groupby('yr_built').price.agg('mean')

# %%
plt.plot(yr_price_avg)

# %% [markdown]
# *This confirms our assumption. The avg. pricing of such houses is between 600000 to 800000*

# %% [markdown]
# **Replacing all 0 price values with $730000**

# %%
df.price.replace(to_replace = 0, value = 735000, inplace = True)
len(df[(df.price == 0)])
# Out:
# C:\Users\Bhargav Bhatt\AppData\Local\Temp\ipykernel_8892\943971067.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.price.replace(to_replace = 0, value = 735000, inplace = True)
# 0

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#    statezip
# 0     98133
# 1     98119
# 2     98042
# 3     98008
# 4     98052

# %% [markdown]
# # Feature reduction

# %% [markdown]
# Since sqft_living is the most important feature and sqft_living & sqft_above are highly corellated we are going  to remove the sqft_above feature.

# %%
df.drop(['sqft_above'], axis = 1, inplace = True)
df.shape
# Out:
# (4597, 13)

# %% [markdown]
# # Handling the index order
# By removing some rows our original dataset index is changed. Let's fix it

# %%
df = df.reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          4597 non-null   int64
#  1   price          4597 non-null   float64
#  2   bedrooms       4597 non-null   int64
#  3   bathrooms      4597 non-null   float64
#  4   sqft_living    4597 non-null   int64
#  5   sqft_lot       4597 non-null   int64
#  6   floors         4597 non-null   float64
#  7   waterfront     4597 non-null   int64
#  8   view           4597 non-null   int64
#  9   condition      4597 non-null   int64
#  10  sqft_basement  4597 non-null   int64
#  11  yr_built       4597 non-null   int64
#  12  yr_renovated   4597 non-null   int64
#  13  statezip       4597 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 502.9 KB

# %%
X = df.iloc[:, 1:]
X.drop("price",inplace=True,axis=1)
X.shape
# Out:
# (4597, 12)

# %%
y = df.price

# %% [markdown]
# Splitting dataset into train and remainder

# %%
from sklearn.model_selection import train_test_split
X_train, X_rem, y_train, y_rem = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
print(len(X_train) / len(df))
# Out:
# 0.8999347400478573

# %% [markdown]
# Splitting remainder into validation and test set

# %%
X_val, X_test, y_val, y_test = train_test_split(X_rem, y_rem, test_size=0.5, random_state=42)
print(len(X_test) / len(y_rem))
# Out:
# 0.5

# %% [markdown]
# Let's print the length of all the 3 splits

# %%
print(len(X_train))
print(len(X_val))
print(len(X_val))
# Out:
# 4137
# 230
# 230

# %% [markdown]
# # Linear regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_val)
mse = mean_squared_error(y_val,y_pred)
mse
# Out:
# 3071058464039.6523

# %%
y_val.head(10)
# Out:
# 1073    175000.0
# 4524    950100.0
# 4434    309487.5
# 2572    427000.0
# 4310    375000.0
# 4017    665000.0
# 4241    759000.0
# 3139    425000.0
# 2283    325000.0
# 4200    679000.0
# Name: price, dtype: float64

# %%
y_pred
# Out:
# array([ 298324.65783553,  889003.03267607,  559616.08179855,
#         352795.01028981,  225189.22086315,  592446.31170739,
#         410896.34614563,  284630.34184651,  356621.74654004,
#         656593.07508065,  728349.2341011 ,  369293.91597877,
#         579986.46178981,  794266.90765053,  384255.06347231,
#         619969.34097027,  386639.22162739,  856295.14754309,
#         446127.45331087,  616606.31431239,  442837.31020478,
#        1301368.83460854,  265585.00982147,  497898.99819295,
#        1833162.6093422 ,  338287.34325227,  722604.2320189 ,
#         388702.9185181 ,  388615.32618972,  381983.13490771,
#         582876.65463954,  608112.97340853,  295891.88693589,
#         367998.41659025,  271027.97045363,  577388.62958975,
#         203790.5313757 ,  241699.90431414,  619869.54065502,
#         929485.98339259,  487703.78728455, 1017988.86896817,
#         442341.34552009,  562241.01124648,  913601.29908631,
#         485396.20054764,  180348.59149237,  609050.50201672,
#         600256.86642903,  186695.81872187,  532386.81500874,
#         430483.52303397,  778319.5324858 ,  382446.36885153,
#         527179.42963119,  467210.14674211,  482782.88114448,
#         350370.84821083,  464765.40814477,  679335.72046726,
#         795396.27213996,  306102.58167779,  342357.09264076,
#         314089.77703913,  357711.00874901,  202405.25624674,
#        1058655.74560204,  547942.85702566,  582831.77378473,
#         528606.0784397 ,  559170.67743113,  483491.69670773,
#         351551.66100279,  303143.37720228,  634629.16639734,
#         616217.00091848,  588835.93008685,  501625.51108286,
#         199431.14340864,  365971.14630184,  476711.52755259,
#         808345.46489436,   82627.64159336,  393543.51743709,
#         451857.35955749,  222272.72356589,  359673.49286039,
#         931937.05510628,  542126.47025016,  630698.64849415,
#         462635.21350325, 1184873.87223721,  252470.54779976,
#         495627.08315087,  833260.38626002,  455303.34945228,
#         485785.46874309,  876890.8039294 ,  289653.41883912,
#         688459.42760555, 1087527.46610365,  704631.57148461,
#         598449.06125394,  457451.05241952,  744812.07688721,
#         422826.04592994,  433216.80641394,  613131.0542283 ,
#         520866.16558556,  715216.52633377,  389590.74550759,
#         731995.70217177,  415809.05006048,  676816.29707853,
#         423131.16684455, 1581756.46736529,  518109.83474372,
#        1152088.3013682 ,  298687.19237532,  528822.04602589,
#         782675.67072303,  452637.98299696,  432319.91557079,
#         647747.09273492, 1165407.52343983,  765680.88985392,
#         412115.05100751,  281521.47629802,  574349.90762177,
#         694272.39677962, 1340524.73650656,  263849.53431753,
#         651518.23639497,  545583.93151515,  432330.2595684 ,
#         452248.73217211,  547006.18559385,  486095.07696547,
#         374175.54693992,  210977.4098172 ,  898414.04134349,
#         377918.4760777 ,  489423.82529142,  699023.8085114 ,
#         476602.88270914,  930259.47882717,  618316.73467484,
#         563613.93287419,  442592.08886747,  669950.62106699,
#         531630.4367191 ,  475103.82635971,  633986.47706356,
#         729604.1651633 , 1030551.90903051,  546825.82836485,
#         541152.20933724,  830179.50294942,  859070.11870246,
#         269567.57425285,  417377.04540543,  439601.52674426,
#         444703.95403863,  393934.95424778,  636099.74940408,
#         178002.61587767,  681711.2110909 ,  619465.46565153,
#         872825.87057832,  875826.07725509,  491552.67633461,
#         330426.57683193,  725904.59132544,  323363.24008445,
#         648034.45019949,  189252.97639928,  229545.74701923,
#         471683.78682123,  640129.83802778,  602060.39627214,
#         718173.00620718,  708774.06200041,  672143.58889753,
#         377964.35568819,  305483.42812501,  328665.03956321,
#        1213468.09797179,  934684.18962068,  414949.79306856,
#         354511.40110729,  160190.98168756,  262941.92190924,
#        1055927.51932912,  378833.83109306,  653393.7666038 ,
#         674651.05446531,  401949.34100744,  484494.08460006,
#         368290.97539402,  813025.81236989,  291235.38651972,
#        1038114.28036648,  287657.72675288,  357096.56081465,
#         275629.30869971,  353294.93538105,  219998.28547249,
#         333112.25925144,  425030.40657531,  564447.53227643,
#        3667033.09182946,  420057.1186688 ,  752195.20426459,
#         381332.06300124,  695925.70622177,  176326.19643238,
#         667670.35156335,  675456.12500651,  833134.62796767,
#         723866.27277988,  254316.53545877,  551065.92352688,
#         343871.58930825,  969938.78952641,  253371.59781068,
#         267414.68350022,  389309.34246851,  285861.07287481,
#         481195.24557307,  339108.95827824])

# %%
X_test.columns = X_test.columns.astype(str)
y_pred_test = lin_reg.predict(X_test)
mse = mean_squared_error(y_test,y_pred_test)
mse
# Out:
# 54436932058.277

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.5950408528169948

# %%
y_test
# Out:
# 3454    450000.0
# 3857    300000.0
# 1818    174500.0
# 856     215000.0
# 1001    430000.0
#           ...
# 3760    392000.0
# 2596    650000.0
# 1839    327500.0
# 1835    320000.0
# 787     317000.0
# Name: price, Length: 230, dtype: float64

# %%
y_pred_test
# Out:
# array([ 388579.08937689,  295375.64718614,  364805.12294984,
#         500688.60810157,  477803.36094489,  719301.58439056,
#         244474.27989797,  469799.0270182 ,  475665.23789317,
#         498993.63954515,  492138.59945133,  303050.14195255,
#         609411.1132448 ,  342312.41838319,  952414.46030537,
#         727593.16715161,  242466.67550648,  294555.03814368,
#        1119549.47353999,  301107.84038054,  818827.28196944,
#         447410.89227414,  459903.06729284,  401862.37571344,
#         396612.17512636,  480311.17476363,  383338.92546774,
#         491641.04078971,  975072.56975193,  660611.00641001,
#         372608.72360142,  449489.28405326,  567046.66853564,
#         835168.75631777,  224917.14332187,  408819.26059827,
#         412308.19147544,  459241.84772604, 1006430.61011337,
#         323996.41413997,  325221.40434296,  454721.52547341,
#         378194.04394841,  563823.41301603,  300652.40121866,
#         564356.87470222,  499105.866016  ,  382432.07855186,
#         539256.14277641,  442385.57633917,  409766.49205625,
#         417964.06375396,  716959.68889973,  213881.40743554,
#         589448.77635244,  449938.63669747,  490282.85458316,
#         457104.82458412, 1618685.81311744,  667406.76081712,
#         517509.79683852,  722018.13913537,  285835.46701106,
#         308624.60124471,  755789.687668  ,  244836.89539347,
#         417572.49446271,  832379.56911096,  482359.21114318,
#         691035.75193363,  818296.75259298,  460903.63829798,
#         576717.58846053,  279073.43478981,  842049.6538939 ,
#         851682.00615443,  579352.81536149,  691583.94230433,
#        1324442.51084208,  225590.05891172,  397746.34691253,
#         258148.88823437,  504046.20396888,  227019.826115  ,
#        1111537.29565801,  736370.34050197,  487072.89726967,
#         768087.21311643,  447236.75702967,  596718.63050382,
#         708363.09611599,  382560.37880954,  451799.7046175 ,
#         424689.82870789,  363551.65322091,  395683.9710182 ,
#         801857.8723349 ,  654861.39276687,  582392.72107666,
#         323791.25049005,  543201.32054213,  420023.02312734,
#         368247.57537117,  335511.97628603,  587112.86103791,
#         386542.90409244,  661556.32694027,  461780.05274317,
#         665162.27662206,  440885.94501294,  416205.57083581,
#         390538.82964886,  550887.9569901 ,  991296.3050574 ,
#         242395.03447232,  794658.56984186,  592938.39673245,
#         465991.96532422,  322488.33073667,  310893.26611453,
#         521368.85261353,  386203.6087314 ,  398369.77463809,
#         397902.16140887,  402297.2795229 ,  851702.45019089,
#         472329.19133225,  639315.58887874,  693642.42894901,
#         294025.77576336,  504081.18965126,  549656.19840181,
#        1627100.6068803 ,  424282.66660629,  455107.32171428,
#         412085.57308679,  278922.02717608,  654462.96145009,
#         514628.23585837,  351138.9023644 ,  152333.39221835,
#         726323.22116952, 1006512.79530128,  407915.1197678 ,
#         670955.06507083,  320197.8151687 ,  328370.75337479,
#         402959.0811859 ,  387631.38988971,  701257.65234558,
#         347271.81317157,  391369.09239776,  386362.6106821 ,
#         613297.11528574,  480392.52553654,  437178.38943276,
#         264725.1704971 ,  585569.00400803,  688278.14745685,
#         346169.26238525,  655640.64894134,  546117.77972807,
#         492039.44187289,  608445.59021209,  390867.85753961,
#         533249.12779363,  554854.77568155,  688044.49487198,
#         656362.95025506,  728484.31273877,  189086.6131924 ,
#         424860.91765219,  868180.01755396,  954341.00149234,
#         573140.40269208,  292759.81113574,  336726.39998176,
#         687964.6812375 ,  508561.79424621,  274698.62728301,
#         430317.28141831, 1169305.32624254,  224523.05015013,
#         896737.51176515,  460815.58196577,  726136.04397255,
#         896561.12235687,  828685.93825372,  442699.0528019 ,
#         894816.57369713,  579779.24996284,  425624.69717038,
#         397499.48816644, 1976277.78929457,  855810.93211359,
#         679761.90617274,  648034.67674846,  883191.70283692,
#         640997.24370593,  720263.02665433,  628831.58327746,
#         342413.77348902,  327890.67551404,  329109.34773359,
#         350360.46458028,  315161.14407977,  819013.58737865,
#         293786.1667147 ,  871014.8730457 ,  583941.68295672,
#         630201.66791178,  420146.44089031,  405879.41168992,
#         349303.58572033,  593765.7926249 ,  444561.3960357 ,
#         716699.97305224,  518837.07916093,  568992.4593214 ,
#         453863.47996528,  789202.4407794 ,  341468.71598542,
#         518547.30007542,  378771.53154115,  490770.05532398,
#         893488.6800787 ,  943276.38253324,  123002.57043091,
#         372919.30681361,  425543.3207916 ])

# %% [markdown]
# # Actual vs. Pridicted Prices

# %%
# Plotting predicted and actual prices over the index for the test set
plt.figure(figsize=(12, 6))
plt.plot(y_test.reset_index(drop=True), label='Actual Prices', color='b', alpha=0.6)
plt.plot(y_pred_test, label='Predicted Prices', color='r', alpha=0.6)
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Predicted and Actual Prices (Test Set)')
plt.legend()
plt.show()

# %% [markdown]
# # Exporting The Model

# %%
import pickle
with open('modelcopy.pkl', 'wb') as file:
    pickle.dump(lin_reg, file)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.5950408528169948
